# %%
# 首先导入包
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import os
import matplotlib.pyplot as plt
import torchvision.models as models
# This is for the progress bar.
from tqdm import tqdm
import seaborn as sns
import json

# %%
json_path="../garbage_classify_et/garbage_classify_rule.json"
with open(json_path,'r',encoding='utf8')as fp:
    json_data=json.load(fp)
    print(json_data["0"])
# Out:
# 其他垃圾/一次性快餐盒

# %%
json_data
# Out:
# {'0': '其他垃圾/一次性快餐盒',
#  '1': '其他垃圾/污损塑料',
#  '2': '其他垃圾/烟蒂',
#  '3': '其他垃圾/牙签',
#  '4': '其他垃圾/破碎花盆及碟碗',
#  '5': '其他垃圾/竹筷',
#  '6': '厨余垃圾/剩饭剩菜',
#  '7': '厨余垃圾/大骨头',
#  '8': '厨余垃圾/水果果皮',
#  '9': '厨余垃圾/水果果肉',
#  '10': '厨余垃圾/茶叶渣',
#  '11': '厨余垃圾/菜叶菜根',
#  '12': '厨余垃圾/蛋壳',
#  '13': '厨余垃圾/鱼骨',
#  '14': '可回收物/充电宝',
#  '15': '可回收物/包',
#  '16': '可回收物/化妆品瓶',
#  '17': '可回收物/塑料玩具',
#  '18': '可回收物/塑料碗盆',
#  '19': '可回收物/塑料衣架',
#  '20': '可回收物/快递纸袋',
#  '21': '可回收物/插头电线',
#  '22': '可回收物/旧衣服',
#  '23': '可回收物/易拉罐',
#  '24': '可回收物/枕头',
#  '25': '可回收物/毛绒玩具',
#  '26': '可回收物/洗发水瓶',
#  '27': '可回收物/玻璃杯',
#  '28': '可回收物/皮鞋',
#  '29': '可回收物/砧板',
#  '30': '可回收物/纸板箱',
#  '31': '可回收物/调料瓶',
#  '32': '可回收物/酒瓶',
#  '33': '可回收物/金属食品罐',
#  '34': '可回收物/锅',
#  '35': '可回收物/食用油桶',
#  '36': '可回收物/饮料瓶',
#  '37': '有害垃圾/干电池',
#  '38': '有害垃圾/软膏',
#  '39': '有害垃圾/过期药物'}

# %%
path="../garbage_classify_et/train_data/"
os.listdir(path)
# Out:
# ['fimg_0.jpg',
#  'fimg_0.txt',
#  'fimg_1.jpg',
#  'fimg_1.txt',
#  'fimg_10.jpg',
#  'fimg_10.txt',
#  'fimg_100.jpg',
#  'fimg_100.txt',
#  'fimg_1000.jpg',
#  'fimg_1000.txt',
#  'fimg_1001.jpg',
#  'fimg_1001.txt',
#  'fimg_1002.jpg',
#  'fimg_1002.txt',
#  'fimg_1003.jpg',
#  'fimg_1003.txt',
#  'fimg_1004.jpg',
#  'fimg_1004.txt',
#  'fimg_1005.jpg',
#  'fimg_1005.txt',
#  'fimg_1006.jpg',
#  'fimg_1006.txt',
#  'fimg_1007.jpg',
#  'fimg_1007.txt',
#  'fimg_1008.jpg',
#  'fimg_1008.txt',
#  'fimg_1009.jpg',
#  'fimg_1009.txt',
#  'fimg_101.jpg',
#  'fimg_101.txt',
#  'fimg_1010.jpg',
#  'fimg_1010.txt',
#  'fimg_1011.jpg',
#  'fimg_1011.txt',
#  'fimg_1012.jpg',
#  'fimg_1012.txt',
#  'fimg_1013.jpg',
#  'fimg_1013.txt',
#  'fimg_1014.jpg',
#  'fimg_1014.txt',
#  'fimg_1015.jpg',
#  'fimg_1015.txt',
#  'fimg_1016.jpg',
#  'fimg_1016.txt',
#  'fimg_1017.jpg',
#  'fimg_1017.txt',
#  'fimg_1018.jpg',
#  'fimg_1018.txt',
#  'fimg_1019.jpg',
#  'fimg_1019.txt',
#  'fimg_102.jpg',
#  'fimg_102.txt',
#  'fimg_1020.jpg',
#  'fimg_1020.txt',
#  'fimg_1021.jpg',
#  'fimg_1021.txt',
#  'fimg_1022.jpg',
#  'fimg_1022.txt',
#  'fimg_1023.jpg',
#  'fimg_1023.txt',
#  'fimg_1024.jpg',
#  'fimg_1024.txt',
#  'fimg_1025.jpg',
#  'fimg_1025.txt',
#  'fimg_1026.jpg',
#  'fimg_1026.txt',
#  'fimg_1027.jpg',
#  'fimg_1027.txt',
#  'fimg_1028.jpg',
#  'fimg_1028.txt',
#  'fimg_1029.jpg',
#  'fimg_1029.txt',
#  'fimg_103.jpg',
#  'fimg_103.txt',
#  'fimg_1030.jpg',
#  'fimg_1030.txt',
#  'fimg_1031.jpg',
#  'fimg_1031.txt',
#  'fimg_1032.jpg',
#  'fimg_1032.txt',
#  'fimg_1033.jpg',
#  'fimg_1033.txt',
#  'fimg_1034.jpg',
#  'fimg_1034.txt',
#  'fimg_1035.jpg',
#  'fimg_1035.txt',
#  'fimg_1036.jpg',
#  'fimg_1036.txt',
#  'fimg_1037.jpg',
#  'fimg_1037.txt',
#  'fimg_1038.jpg',
#  'fimg_1038.txt',
#  'fimg_1039.jpg',
#  'fimg_1039.txt',
#  'fimg_104.jpg',
#  'fimg_104.txt',
#  'fimg_1040.jpg',
#  'fimg_1040.txt',
#  'fimg_1041.jpg',
#  'fimg_1041.txt',
#  'fimg_1042.jpg',
#  'fimg_1042.txt',
#  'fimg_1043.jpg',
#  'fimg_1043.txt',
#  'fimg_1044.jpg',
#  'fimg_1044.txt',
#  'fimg_1045.jpg',
#  'fimg_1045.txt',
#  'fimg_1046.jpg',
#  'fimg_1046.txt',
#  'fimg_1047.jpg',
#  'fimg_1047.txt',
#  'fimg_1048.jpg',
#  'fimg_1048.txt',
#  'fimg_1049.jpg',
#  'fimg_1049.txt',
#  'fimg_105.jpg',
#  'fimg_105.txt',
#  'fimg_1050.jpg',
#  'fimg_1050.txt',
#  'fimg_1051.jpg',
#  'fimg_1051.txt',
#  'fimg_1052.jpg',
#  'fimg_1052.txt',
#  'fimg_1053.jpg',
#  'fimg_1053.txt',
#  'fimg_1054.jpg',
#  'fimg_1054.txt',
#  'fimg_1055.jpg',
#  'fimg_1055.txt',
#  'fimg_1056.jpg',
#  'fimg_1056.txt',
#  'fimg_1057.jpg',
#  'fimg_1057.txt',
#  'fimg_1058.jpg',
#  'fimg_1058.txt',
#  'fimg_1059.jpg',
#  'fimg_1059.txt',
#  'fimg_106.jpg',
#  'fimg_106.txt',
#  'fimg_1060.jpg',
#  'fimg_1060.txt',
#  'fimg_1061.jpg',
#  'fimg_1061.txt',
#  'fimg_1062.jpg',
#  'fimg_1062.txt',
#  'fimg_1063.jpg',
#  'fimg_1063.txt',
#  'fimg_1064.jpg',
#  'fimg_1064.txt',
#  'fimg_1065.jpg',
#  'fimg_1065.txt',
#  'fimg_1066.jpg',
#  'fimg_1066.txt',
#  'fimg_1067.jpg',
#  'fimg_1067.txt',
#  'fimg_1068.jpg',
#  'fimg_1068.txt',
#  'fimg_1069.jpg',
#  'fimg_1069.txt',
#  'fimg_107.jpg',
#  'fimg_107.txt',
#  'fimg_1070.jpg',
#  'fimg_1070.txt',
#  'fimg_1071.jpg',
#  'fimg_1071.txt',
#  'fimg_1072.jpg',
#  'fimg_1072.txt',
#  'fimg_1073.jpg',
#  'fimg_1073.txt',
#  'fimg_1074.jpg',
#  'fimg_1074.txt',
#  'fimg_1075.jpg',
#  'fimg_1075.txt',
#  'fimg_1076.jpg',
#  'fimg_1076.txt',
#  'fimg_1077.jpg',
#  'fimg_1077.txt',
#  'fimg_1078.jpg',
#  'fimg_1078.txt',
#  'fimg_1079.jpg',
#  'fimg_1079.txt',
#  'fimg_108.jpg',
#  'fimg_108.txt',
#  'fimg_1080.jpg',
#  'fimg_1080.txt',
#  'fimg_1081.jpg',
#  'fimg_1081.txt',
#  'fimg_1082.jpg',
#  'fimg_1082.txt',
#  'fimg_1083.jpg',
#  'fimg_1083.txt',
#  'fimg_1084.jpg',
#  'fimg_1084.txt',
#  'fimg_1085.jpg',
#  'fimg_1085.txt',
#  'fimg_1086.jpg',
#  'fimg_1086.txt',
#  'fimg_1087.jpg',
#  'fimg_1087.txt',
#  'fimg_1088.jpg',
#  'fimg_1088.txt',
#  'fimg_1089.jpg',
#  'fimg_1089.txt',
#  'fimg_109.jpg',
#  'fimg_109.txt',
#  'fimg_1090.jpg',
#  'fimg_1090.txt',
#  'fimg_1091.jpg',
#  'fimg_1091.txt',
#  'fimg_1092.jpg',
#  'fimg_1092.txt',
#  'fimg_1093.jpg',
#  'fimg_1093.txt',
#  'fimg_1094.jpg',
#  'fimg_1094.txt',
#  'fimg_1095.jpg',
#  'fimg_1095.txt',
#  'fimg_1096.jpg',
#  'fimg_1096.txt',
#  'fimg_1097.jpg',
#  'fimg_1097.txt',
#  'fimg_1098.jpg',
#  'fimg_1098.txt',
#  'fimg_1099.jpg',
#  'fimg_1099.txt',
#  'fimg_11.jpg',
#  'fimg_11.txt',
#  'fimg_110.jpg',
#  'fimg_110.txt',
#  'fimg_1100.jpg',
#  'fimg_1100.txt',
#  'fimg_1101.jpg',
#  'fimg_1101.txt',
#  'fimg_1102.jpg',
#  'fimg_1102.txt',
#  'fimg_1103.jpg',
#  'fimg_1103.txt',
#  'fimg_1104.jpg',
#  'fimg_1104.txt',
#  'fimg_1105.jpg',
#  'fimg_1105.txt',
#  'fimg_1106.jpg',
#  'fimg_1106.txt',
#  'fimg_1107.jpg',
#  'fimg_1107.txt',
#  'fimg_1108.jpg',
#  'fimg_1108.txt',
#  'fimg_1109.jpg',
#  'fimg_1109.txt',
#  'fimg_111.jpg',
#  'fimg_111.txt',
#  'fimg_1110.jpg',
#  'fimg_1110.txt',
#  'fimg_1111.jpg',
#  'fimg_1111.txt',
#  'fimg_1112.jpg',
#  'fimg_1112.txt',
#  'fimg_1113.jpg',
#  'fimg_1113.txt',
#  'fimg_1114.jpg',
#  'fimg_1114.txt',
#  'fimg_1115.jpg',
#  'fimg_1115.txt',
#  'fimg_1116.jpg',
#  'fimg_1116.txt',
#  'fimg_1117.jpg',
#  'fimg_1117.txt',
#  'fimg_1118.jpg',
#  'fimg_1118.txt',
#  'fimg_1119.jpg',
#  'fimg_1119.txt',
#  'fimg_112.jpg',
#  'fimg_112.txt',
#  'fimg_1120.jpg',
#  'fimg_1120.txt',
#  'fimg_1121.jpg',
#  'fimg_1121.txt',
#  'fimg_1122.jpg',
#  'fimg_1122.txt',
#  'fimg_1123.jpg',
#  'fimg_1123.txt',
#  'fimg_1124.jpg',
#  'fimg_1124.txt',
#  'fimg_1125.jpg',
#  'fimg_1125.txt',
#  'fimg_1126.jpg',
#  'fimg_1126.txt',
#  'fimg_1127.jpg',
#  'fimg_1127.txt',
#  'fimg_1128.jpg',
#  'fimg_1128.txt',
#  'fimg_1129.jpg',
#  'fimg_1129.txt',
#  'fimg_113.jpg',
#  'fimg_113.txt',
#  'fimg_1130.jpg',
#  'fimg_1130.txt',
#  'fimg_1131.jpg',
#  'fimg_1131.txt',
#  'fimg_1132.jpg',
#  'fimg_1132.txt',
#  'fimg_1133.jpg',
#  'fimg_1133.txt',
#  'fimg_1134.jpg',
#  'fimg_1134.txt',
#  'fimg_1135.jpg',
#  'fimg_1135.txt',
#  'fimg_1136.jpg',
#  'fimg_1136.txt',
#  'fimg_1137.jpg',
#  'fimg_1137.txt',
#  'fimg_1138.jpg',
#  'fimg_1138.txt',
#  'fimg_1139.jpg',
#  'fimg_1139.txt',
#  'fimg_114.jpg',
#  'fimg_114.txt',
#  'fimg_1140.jpg',
#  'fimg_1140.txt',
#  'fimg_1141.jpg',
#  'fimg_1141.txt',
#  'fimg_1142.jpg',
#  'fimg_1142.txt',
#  'fimg_1143.jpg',
#  'fimg_1143.txt',
#  'fimg_1144.jpg',
#  'fimg_1144.txt',
#  'fimg_1145.jpg',
#  'fimg_1145.txt',
#  'fimg_1146.jpg',
#  'fimg_1146.txt',
#  'fimg_1147.jpg',
#  'fimg_1147.txt',
#  'fimg_1148.jpg',
#  'fimg_1148.txt',
#  'fimg_1149.jpg',
#  'fimg_1149.txt',
#  'fimg_115.jpg',
#  'fimg_115.txt',
#  'fimg_1150.jpg',
#  'fimg_1150.txt',
#  'fimg_1151.jpg',
#  'fimg_1151.txt',
#  'fimg_1152.jpg',
#  'fimg_1152.txt',
#  'fimg_1153.jpg',
#  'fimg_1153.txt',
#  'fimg_1154.jpg',
#  'fimg_1154.txt',
#  'fimg_1155.jpg',
#  'fimg_1155.txt',
#  'fimg_1156.jpg',
#  'fimg_1156.txt',
#  'fimg_1157.jpg',
#  'fimg_1157.txt',
#  'fimg_1158.jpg',
#  'fimg_1158.txt',
#  'fimg_1159.jpg',
#  'fimg_1159.txt',
#  'fimg_116.jpg',
#  'fimg_116.txt',
#  'fimg_1160.jpg',
#  'fimg_1160.txt',
#  'fimg_1161.jpg',
#  'fimg_1161.txt',
#  'fimg_1162.jpg',
#  'fimg_1162.txt',
#  'fimg_1163.jpg',
#  'fimg_1163.txt',
#  'fimg_1164.jpg',
#  'fimg_1164.txt',
#  'fimg_1165.jpg',
#  'fimg_1165.txt',
#  'fimg_1166.jpg',
#  'fimg_1166.txt',
#  'fimg_1167.jpg',
#  'fimg_1167.txt',
#  'fimg_1168.jpg',
#  'fimg_1168.txt',
#  'fimg_1169.jpg',
#  'fimg_1169.txt',
#  'fimg_117.jpg',
#  'fimg_117.txt',
#  'fimg_1170.jpg',
#  'fimg_1170.txt',
#  'fimg_1171.jpg',
#  'fimg_1171.txt',
#  'fimg_1172.jpg',
#  'fimg_1172.txt',
#  'fimg_1173.jpg',
#  'fimg_1173.txt',
#  'fimg_1174.jpg',
#  'fimg_1174.txt',
#  'fimg_1175.jpg',
#  'fimg_1175.txt',
#  'fimg_1176.jpg',
#  'fimg_1176.txt',
#  'fimg_1177.jpg',
#  'fimg_1177.txt',
#  'fimg_1178.jpg',
#  'fimg_1178.txt',
#  'fimg_1179.jpg',
#  'fimg_1179.txt',
#  'fimg_118.jpg',
#  'fimg_118.txt',
#  'fimg_1180.jpg',
#  'fimg_1180.txt',
#  'fimg_1181.jpg',
#  'fimg_1181.txt',
#  'fimg_1182.jpg',
#  'fimg_1182.txt',
#  'fimg_1183.jpg',
#  'fimg_1183.txt',
#  'fimg_1184.jpg',
#  'fimg_1184.txt',
#  'fimg_1185.jpg',
#  'fimg_1185.txt',
#  'fimg_1186.jpg',
#  'fimg_1186.txt',
#  'fimg_1187.jpg',
#  'fimg_1187.txt',
#  'fimg_1188.jpg',
#  'fimg_1188.txt',
#  'fimg_1189.jpg',
#  'fimg_1189.txt',
#  'fimg_119.jpg',
#  'fimg_119.txt',
#  'fimg_1190.jpg',
#  'fimg_1190.txt',
#  'fimg_1191.jpg',
#  'fimg_1191.txt',
#  'fimg_1192.jpg',
#  'fimg_1192.txt',
#  'fimg_1193.jpg',
#  'fimg_1193.txt',
#  'fimg_1194.jpg',
#  'fimg_1194.txt',
#  'fimg_1195.jpg',
#  'fimg_1195.txt',
#  'fimg_1196.jpg',
#  'fimg_1196.txt',
#  'fimg_1197.jpg',
#  'fimg_1197.txt',
#  'fimg_1198.jpg',
#  'fimg_1198.txt',
#  'fimg_1199.jpg',
#  'fimg_1199.txt',
#  'fimg_12.jpg',
#  'fimg_12.txt',
#  'fimg_120.jpg',
#  'fimg_120.txt',
#  'fimg_1200.jpg',
#  'fimg_1200.txt',
#  'fimg_1201.jpg',
#  'fimg_1201.txt',
#  'fimg_1202.jpg',
#  'fimg_1202.txt',
#  'fimg_1203.jpg',
#  'fimg_1203.txt',
#  'fimg_1204.jpg',
#  'fimg_1204.txt',
#  'fimg_1205.jpg',
#  'fimg_1205.txt',
#  'fimg_1206.jpg',
#  'fimg_1206.txt',
#  'fimg_1207.jpg',
#  'fimg_1207.txt',
#  'fimg_1208.jpg',
#  'fimg_1208.txt',
#  'fimg_1209.jpg',
#  'fimg_1209.txt',
#  'fimg_121.jpg',
#  'fimg_121.txt',
#  'fimg_1210.jpg',
#  'fimg_1210.txt',
#  'fimg_1211.jpg',
#  'fimg_1211.txt',
#  'fimg_1212.jpg',
#  'fimg_1212.txt',
#  'fimg_1213.jpg',
#  'fimg_1213.txt',
#  'fimg_1214.jpg',
#  'fimg_1214.txt',
#  'fimg_1215.jpg',
#  'fimg_1215.txt',
#  'fimg_1216.jpg',
#  'fimg_1216.txt',
#  'fimg_1217.jpg',
#  'fimg_1217.txt',
#  'fimg_1218.jpg',
#  'fimg_1218.txt',
#  'fimg_1219.jpg',
#  'fimg_1219.txt',
#  'fimg_122.jpg',
#  'fimg_122.txt',
#  'fimg_1220.jpg',
#  'fimg_1220.txt',
#  'fimg_1221.jpg',
#  'fimg_1221.txt',
#  'fimg_1222.jpg',
#  'fimg_1222.txt',
#  'fimg_1223.jpg',
#  'fimg_1223.txt',
#  'fimg_1224.jpg',
#  'fimg_1224.txt',
#  'fimg_1225.jpg',
#  'fimg_1225.txt',
#  'fimg_1226.jpg',
#  'fimg_1226.txt',
#  'fimg_1227.jpg',
#  'fimg_1227.txt',
#  'fimg_1228.jpg',
#  'fimg_1228.txt',
#  'fimg_1229.jpg',
#  'fimg_1229.txt',
#  'fimg_123.jpg',
#  'fimg_123.txt',
#  'fimg_1230.jpg',
#  'fimg_1230.txt',
#  'fimg_1231.jpg',
#  'fimg_1231.txt',
#  'fimg_1232.jpg',
#  'fimg_1232.txt',
#  'fimg_1233.jpg',
#  'fimg_1233.txt',
#  'fimg_1234.jpg',
#  'fimg_1234.txt',
#  'fimg_1235.jpg',
#  'fimg_1235.txt',
#  'fimg_1236.jpg',
#  'fimg_1236.txt',
#  'fimg_1237.jpg',
#  'fimg_1237.txt',
#  'fimg_1238.jpg',
#  'fimg_1238.txt',
#  'fimg_1239.jpg',
#  'fimg_1239.txt',
#  'fimg_124.jpg',
#  'fimg_124.txt',
#  'fimg_1240.jpg',
#  'fimg_1240.txt',
#  'fimg_1241.jpg',
#  'fimg_1241.txt',
#  'fimg_1242.jpg',
#  'fimg_1242.txt',
#  'fimg_1243.jpg',
#  'fimg_1243.txt',
#  'fimg_1244.jpg',
#  'fimg_1244.txt',
#  'fimg_1245.jpg',
#  'fimg_1245.txt',
#  'fimg_1246.jpg',
#  'fimg_1246.txt',
#  'fimg_1247.jpg',
#  'fimg_1247.txt',
#  'fimg_1248.jpg',
#  'fimg_1248.txt',
#  'fimg_1249.jpg',
#  'fimg_1249.txt',
#  'fimg_125.jpg',
#  'fimg_125.txt',
#  'fimg_1250.jpg',
#  'fimg_1250.txt',
#  'fimg_1251.jpg',
#  'fimg_1251.txt',
#  'fimg_1252.jpg',
#  'fimg_1252.txt',
#  'fimg_1253.jpg',
#  'fimg_1253.txt',
#  'fimg_1254.jpg',
#  'fimg_1254.txt',
#  'fimg_1255.jpg',
#  'fimg_1255.txt',
#  'fimg_1256.jpg',
#  'fimg_1256.txt',
#  'fimg_1257.jpg',
#  'fimg_1257.txt',
#  'fimg_1258.jpg',
#  'fimg_1258.txt',
#  'fimg_1259.jpg',
#  'fimg_1259.txt',
#  'fimg_126.jpg',
#  'fimg_126.txt',
#  'fimg_1260.jpg',
#  'fimg_1260.txt',
#  'fimg_1261.jpg',
#  'fimg_1261.txt',
#  'fimg_1262.jpg',
#  'fimg_1262.txt',
#  'fimg_1263.jpg',
#  'fimg_1263.txt',
#  'fimg_1264.jpg',
#  'fimg_1264.txt',
#  'fimg_1265.jpg',
#  'fimg_1265.txt',
#  'fimg_1266.jpg',
#  'fimg_1266.txt',
#  'fimg_1267.jpg',
#  'fimg_1267.txt',
#  'fimg_1268.jpg',
#  'fimg_1268.txt',
#  'fimg_1269.jpg',
#  'fimg_1269.txt',
#  'fimg_127.jpg',
#  'fimg_127.txt',
#  'fimg_1270.jpg',
#  'fimg_1270.txt',
#  'fimg_1271.jpg',
#  'fimg_1271.txt',
#  'fimg_1272.jpg',
#  'fimg_1272.txt',
#  'fimg_1273.jpg',
#  'fimg_1273.txt',
#  'fimg_1274.jpg',
#  'fimg_1274.txt',
#  'fimg_1275.jpg',
#  'fimg_1275.txt',
#  'fimg_1276.jpg',
#  'fimg_1276.txt',
#  'fimg_1277.jpg',
#  'fimg_1277.txt',
#  'fimg_1278.jpg',
#  'fimg_1278.txt',
#  'fimg_1279.jpg',
#  'fimg_1279.txt',
#  'fimg_128.jpg',
#  'fimg_128.txt',
#  'fimg_1280.jpg',
#  'fimg_1280.txt',
#  'fimg_1281.jpg',
#  'fimg_1281.txt',
#  'fimg_1282.jpg',
#  'fimg_1282.txt',
#  'fimg_1283.jpg',
#  'fimg_1283.txt',
#  'fimg_1284.jpg',
#  'fimg_1284.txt',
#  'fimg_1285.jpg',
#  'fimg_1285.txt',
#  'fimg_1286.jpg',
#  'fimg_1286.txt',
#  'fimg_1287.jpg',
#  'fimg_1287.txt',
#  'fimg_1288.jpg',
#  'fimg_1288.txt',
#  'fimg_1289.jpg',
#  'fimg_1289.txt',
#  'fimg_129.jpg',
#  'fimg_129.txt',
#  'fimg_1290.jpg',
#  'fimg_1290.txt',
#  'fimg_1291.jpg',
#  'fimg_1291.txt',
#  'fimg_1292.jpg',
#  'fimg_1292.txt',
#  'fimg_1293.jpg',
#  'fimg_1293.txt',
#  'fimg_1294.jpg',
#  'fimg_1294.txt',
#  'fimg_1295.jpg',
#  'fimg_1295.txt',
#  'fimg_1296.jpg',
#  'fimg_1296.txt',
#  'fimg_1297.jpg',
#  'fimg_1297.txt',
#  'fimg_1298.jpg',
#  'fimg_1298.txt',
#  'fimg_1299.jpg',
#  'fimg_1299.txt',
#  'fimg_13.jpg',
#  'fimg_13.txt',
#  'fimg_130.jpg',
#  'fimg_130.txt',
#  'fimg_1300.jpg',
#  'fimg_1300.txt',
#  'fimg_1301.jpg',
#  'fimg_1301.txt',
#  'fimg_1302.jpg',
#  'fimg_1302.txt',
#  'fimg_1303.jpg',
#  'fimg_1303.txt',
#  'fimg_1304.jpg',
#  'fimg_1304.txt',
#  'fimg_1305.jpg',
#  'fimg_1305.txt',
#  'fimg_1306.jpg',
#  'fimg_1306.txt',
#  'fimg_1307.jpg',
#  'fimg_1307.txt',
#  'fimg_1308.jpg',
#  'fimg_1308.txt',
#  'fimg_1309.jpg',
#  'fimg_1309.txt',
#  'fimg_131.jpg',
#  'fimg_131.txt',
#  'fimg_1310.jpg',
#  'fimg_1310.txt',
#  'fimg_1311.jpg',
#  'fimg_1311.txt',
#  'fimg_1312.jpg',
#  'fimg_1312.txt',
#  'fimg_1313.jpg',
#  'fimg_1313.txt',
#  'fimg_1314.jpg',
#  'fimg_1314.txt',
#  'fimg_1315.jpg',
#  'fimg_1315.txt',
#  'fimg_1316.jpg',
#  'fimg_1316.txt',
#  'fimg_1317.jpg',
#  'fimg_1317.txt',
#  'fimg_1318.jpg',
#  'fimg_1318.txt',
#  'fimg_1319.jpg',
#  'fimg_1319.txt',
#  'fimg_132.jpg',
#  'fimg_132.txt',
#  'fimg_1320.jpg',
#  'fimg_1320.txt',
#  'fimg_1321.jpg',
#  'fimg_1321.txt',
#  'fimg_1322.jpg',
#  'fimg_1322.txt',
#  'fimg_1323.jpg',
#  'fimg_1323.txt',
#  'fimg_1324.jpg',
#  'fimg_1324.txt',
#  'fimg_1325.jpg',
#  'fimg_1325.txt',
#  'fimg_1326.jpg',
#  'fimg_1326.txt',
#  'fimg_1327.jpg',
#  'fimg_1327.txt',
#  'fimg_1328.jpg',
#  'fimg_1328.txt',
#  'fimg_1329.jpg',
#  'fimg_1329.txt',
#  'fimg_133.jpg',
#  'fimg_133.txt',
#  'fimg_1330.jpg',
#  'fimg_1330.txt',
#  'fimg_1331.jpg',
#  'fimg_1331.txt',
#  'fimg_1332.jpg',
#  'fimg_1332.txt',
#  'fimg_1333.jpg',
#  'fimg_1333.txt',
#  'fimg_1334.jpg',
#  'fimg_1334.txt',
#  'fimg_1335.jpg',
#  'fimg_1335.txt',
#  'fimg_1336.jpg',
#  'fimg_1336.txt',
#  'fimg_1337.jpg',
#  'fimg_1337.txt',
#  'fimg_1338.jpg',
#  'fimg_1338.txt',
#  'fimg_1339.jpg',
#  'fimg_1339.txt',
#  'fimg_134.jpg',
#  'fimg_134.txt',
#  'fimg_1340.jpg',
#  'fimg_1340.txt',
#  'fimg_1341.jpg',
#  'fimg_1341.txt',
#  'fimg_1342.jpg',
#  'fimg_1342.txt',
#  'fimg_1343.jpg',
#  'fimg_1343.txt',
#  'fimg_1344.jpg',
#  'fimg_1344.txt',
#  'fimg_1345.jpg',
#  'fimg_1345.txt',
#  'fimg_1346.jpg',
#  'fimg_1346.txt',
#  'fimg_1347.jpg',
#  'fimg_1347.txt',
#  'fimg_1348.jpg',
#  'fimg_1348.txt',
#  'fimg_1349.jpg',
#  'fimg_1349.txt',
#  'fimg_1350.jpg',
#  'fimg_1350.txt',
#  'fimg_1351.jpg',
#  'fimg_1351.txt',
#  'fimg_1352.jpg',
#  'fimg_1352.txt',
#  'fimg_1353.jpg',
#  'fimg_1353.txt',
#  'fimg_1354.jpg',
#  'fimg_1354.txt',
#  'fimg_1355.jpg',
#  'fimg_1355.txt',
#  'fimg_1356.jpg',
#  'fimg_1356.txt',
#  'fimg_1357.jpg',
#  'fimg_1357.txt',
#  'fimg_1358.jpg',
#  'fimg_1358.txt',
#  'fimg_1359.jpg',
#  'fimg_1359.txt',
#  'fimg_136.jpg',
#  'fimg_136.txt',
#  'fimg_1360.jpg',
#  'fimg_1360.txt',
#  'fimg_1361.jpg',
#  'fimg_1361.txt',
#  'fimg_1362.jpg',
#  'fimg_1362.txt',
#  'fimg_1363.jpg',
#  'fimg_1363.txt',
#  'fimg_1364.jpg',
#  'fimg_1364.txt',
#  'fimg_1365.jpg',
#  'fimg_1365.txt',
#  'fimg_1366.jpg',
#  'fimg_1366.txt',
#  'fimg_1367.jpg',
#  'fimg_1367.txt',
#  'fimg_1368.jpg',
#  'fimg_1368.txt',
#  'fimg_1369.jpg',
#  'fimg_1369.txt',
#  'fimg_137.jpg',
#  'fimg_137.txt',
#  'fimg_1370.jpg',
#  'fimg_1370.txt',
#  'fimg_1371.jpg',
#  'fimg_1371.txt',
#  'fimg_1372.jpg',
#  'fimg_1372.txt',
#  'fimg_1373.jpg',
#  'fimg_1373.txt',
#  'fimg_1374.jpg',
#  'fimg_1374.txt',
#  'fimg_1375.jpg',
#  'fimg_1375.txt',
#  'fimg_1376.jpg',
#  'fimg_1376.txt',
#  'fimg_1377.jpg',
#  'fimg_1377.txt',
#  'fimg_1378.jpg',
#  'fimg_1378.txt',
#  'fimg_1379.jpg',
#  'fimg_1379.txt',
#  'fimg_138.jpg',
#  'fimg_138.txt',
#  'fimg_1380.jpg',
#  'fimg_1380.txt',
#  'fimg_1381.jpg',
#  'fimg_1381.txt',
#  'fimg_1382.jpg',
#  'fimg_1382.txt',
#  'fimg_1383.jpg',
#  'fimg_1383.txt',
#  'fimg_1384.jpg',
#  'fimg_1384.txt',
#  'fimg_1385.jpg',
#  'fimg_1385.txt',
#  'fimg_1386.jpg',
#  'fimg_1386.txt',
#  'fimg_1387.jpg',
#  'fimg_1387.txt',
#  'fimg_1388.jpg',
#  'fimg_1388.txt',
#  'fimg_1389.jpg',
#  'fimg_1389.txt',
#  'fimg_139.jpg',
#  'fimg_139.txt',
#  'fimg_1390.jpg',
#  'fimg_1390.txt',
#  'fimg_1391.jpg',
#  'fimg_1391.txt',
#  'fimg_1392.jpg',
#  'fimg_1392.txt',
#  'fimg_1393.jpg',
#  'fimg_1393.txt',
#  'fimg_1394.jpg',
#  'fimg_1394.txt',
#  'fimg_1395.jpg',
#  'fimg_1395.txt',
#  'fimg_1396.jpg',
#  'fimg_1396.txt',
#  'fimg_1397.jpg',
#  'fimg_1397.txt',
#  'fimg_1398.jpg',
#  'fimg_1398.txt',
#  'fimg_1399.jpg',
#  'fimg_1399.txt',
#  'fimg_14.jpg',
#  'fimg_14.txt',
#  'fimg_140.jpg',
#  'fimg_140.txt',
#  'fimg_1400.jpg',
#  'fimg_1400.txt',
#  'fimg_1401.jpg',
#  'fimg_1401.txt',
#  'fimg_1402.jpg',
#  'fimg_1402.txt',
#  'fimg_1403.jpg',
#  'fimg_1403.txt',
#  'fimg_1404.jpg',
#  'fimg_1404.txt',
#  'fimg_1405.jpg',
#  'fimg_1405.txt',
#  'fimg_1406.jpg',
#  'fimg_1406.txt',
#  'fimg_1407.jpg',
#  'fimg_1407.txt',
#  'fimg_1408.jpg',
#  'fimg_1408.txt',
#  'fimg_1409.jpg',
#  'fimg_1409.txt',
#  'fimg_141.jpg',
#  'fimg_141.txt',
#  'fimg_1410.jpg',
#  'fimg_1410.txt',
#  'fimg_1411.jpg',
#  'fimg_1411.txt',
#  'fimg_1412.jpg',
#  'fimg_1412.txt',
#  'fimg_1413.jpg',
#  'fimg_1413.txt',
#  'fimg_1414.jpg',
#  'fimg_1414.txt',
#  'fimg_1415.jpg',
#  'fimg_1415.txt',
#  'fimg_1416.jpg',
#  'fimg_1416.txt',
#  'fimg_1417.jpg',
#  'fimg_1417.txt',
#  'fimg_1418.jpg',
#  'fimg_1418.txt',
#  'fimg_1419.jpg',
#  'fimg_1419.txt',
#  'fimg_142.jpg',
#  'fimg_142.txt',
#  'fimg_1420.jpg',
#  'fimg_1420.txt',
#  'fimg_1421.jpg',
#  'fimg_1421.txt',
#  'fimg_1422.jpg',
#  'fimg_1422.txt',
#  'fimg_1423.jpg',
#  'fimg_1423.txt',
#  'fimg_1424.jpg',
#  'fimg_1424.txt',
#  'fimg_1425.jpg',
#  'fimg_1425.txt',
#  'fimg_1426.jpg',
#  'fimg_1426.txt',
#  'fimg_1427.jpg',
#  'fimg_1427.txt',
#  'fimg_1428.jpg',
#  'fimg_1428.txt',
#  'fimg_1429.jpg',
#  'fimg_1429.txt',
#  'fimg_143.jpg',
#  'fimg_143.txt',
#  'fimg_1430.jpg',
#  'fimg_1430.txt',
#  'fimg_1431.jpg',
#  'fimg_1431.txt',
#  'fimg_1432.jpg',
#  'fimg_1432.txt',
#  'fimg_1433.jpg',
#  'fimg_1433.txt',
#  'fimg_1434.jpg',
#  'fimg_1434.txt',
#  'fimg_1435.jpg',
#  'fimg_1435.txt',
#  'fimg_1436.jpg',
#  'fimg_1436.txt',
#  'fimg_1437.jpg',
#  'fimg_1437.txt',
#  'fimg_1438.jpg',
#  'fimg_1438.txt',
#  'fimg_1439.jpg',
#  'fimg_1439.txt',
#  'fimg_144.jpg',
#  'fimg_144.txt',
#  'fimg_1440.jpg',
#  'fimg_1440.txt',
#  'fimg_1441.jpg',
#  'fimg_1441.txt',
#  'fimg_1442.jpg',
#  'fimg_1442.txt',
#  'fimg_1443.jpg',
#  'fimg_1443.txt',
#  'fimg_1444.jpg',
#  'fimg_1444.txt',
#  'fimg_1445.jpg',
#  'fimg_1445.txt',
#  'fimg_1446.jpg',
#  'fimg_1446.txt',
#  'fimg_1447.jpg',
#  'fimg_1447.txt',
#  'fimg_1448.jpg',
#  'fimg_1448.txt',
#  ...]

# %%
def to_dataframe(file_path,json_path):
    """
    将图片和标签转为dataframe格式方面查看分布和图片样例
    """
    combine=os.listdir(file_path)
   
    combine.sort(key=lambda x: int(x.split('.')[0].split('_')[-1]))
    imgs=[]
    labels=[]
    label_explan=[]
    with open(json_path,'r',encoding='utf8')as fp:
        json_data=json.load(fp)
    for item in combine:
        if(item.split('.')[-1]=='jpg'):
            img_path=os.path.join(file_path,item)
            
            
            imgs.append(img_path)
            label_path=os.path.join(file_path,item.split('.')[0]+'.txt')
            with open (label_path,'r') as f:
                label=int(f.read().split(',')[-1])
            label_explan.append(json_data[str(label)])
            labels.append(str(label))
            
    
    df=pd.DataFrame()

    df['img_path']=imgs
    df['label']=labels
    df['label_explain']=label_explan
    
    
    return df

# %%
df=to_dataframe(path,json_path)

# %%
df.to_csv("garbage_classify_et.csv")

# %%
df.describe()
# Out:
#                                             img_path label label_explain
# count                                           4165  4165          4165
# unique                                          4165    40            40
# top     ../garbage_classify_et/train_data/fimg_0.jpg    17     可回收物/塑料玩具
# freq                                               1   431           431

# %%
#解决sns无法展示中文
from matplotlib.font_manager import FontProperties
myfont=FontProperties(fname=r'C:\Windows\Fonts\simhei.ttf',size=15)
sns.set(font=myfont.get_name())

def barw(ax): 
    
    for p in ax.patches:
        val = p.get_width() #height of the bar
        x = p.get_x()+ p.get_width() # x- position 
        y = p.get_y() + p.get_height()/2 #y-position
        ax.annotate(round(val,2),(x,y))
        
#finding top leaves

plt.figure(figsize = (15,30))
ax0 =sns.countplot(y=df['label_explain'],order=df['label_explain'].value_counts().index)
barw(ax0)
plt.show()

# %%
df['label_explain'].iloc[0]
# Out:
# '其他垃圾/一次性快餐盒'

# %%
def big_class(old_df):
    """
    将/前的类合并 构建更粗粒度的分类标签数据集
    """
    old_df['category']=old_df['label_explain'].apply(lambda x:x.split('/')[0])
    return old_df

# %%
df=big_class(df)

# %%
df[df['label']=='28']
# Out:
#                                              img_path label label_explain  \
# 3327  ../garbage_classify_et/train_data/fimg_3349.jpg    28       可回收物/皮鞋
# 3328  ../garbage_classify_et/train_data/fimg_3350.jpg    28       可回收物/皮鞋
# 3329  ../garbage_classify_et/train_data/fimg_3351.jpg    28       可回收物/皮鞋
# 3330  ../garbage_classify_et/train_data/fimg_3352.jpg    28       可回收物/皮鞋
# 3331  ../garbage_classify_et/train_data/fimg_3353.jpg    28       可回收物/皮鞋
# ...                                               ...   ...           ...
# 3425  ../garbage_classify_et/train_data/fimg_3447.jpg    28       可回收物/皮鞋
# 3426  ../garbage_classify_et/train_data/fimg_3448.jpg    28       可回收物/皮鞋
# 3427  ../garbage_classify_et/train_data/fimg_3449.jpg    28       可回收物/皮鞋
# 3428  ../garbage_classify_et/train_data/fimg_3450.jpg    28       可回收物/皮鞋
# 3429  ../garbage_classify_et/train_data/fimg_3451.jpg    28       可回收物/皮鞋
#
#      category
# 3327     可回收物
# 3328     可回收物
# 3329     可回收物
# 3330     可回收物
# 3331     可回收物
# ...       ...
# 3425     可回收物
# 3426     可回收物
# 3427     可回收物
# 3428     可回收物
# 3429     可回收物
#
# [103 rows x 4 columns]

# %%
plt.figure(figsize = (15,30))
ax0 =sns.countplot(y=df['category'],order=df['category'].value_counts().index)
barw(ax0)
plt.show()

# %%
df.to_csv("garbage_classify_et.csv")

# %%
df.iloc[:,1]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 4160    32
# 4161    32
# 4162    32
# 4163    32
# 4164    32
# Name: label, Length: 4165, dtype: object

# %%
class GarbageData(Dataset):
    def __init__(self, csv_path, file_path, mode='train', valid_ratio=0.2, resize_height=256, resize_width=256):
        """
        csv_path:储存路径信息
        file_path:图片所在路径
        
        
        """
        self.resize_height = resize_height
        self.resize_width = resize_width

        self.file_path = file_path
        self.mode = mode
        # 读取 csv 文件
        # 利用pandas读取csv文件
        self.data_info = pd.read_csv(csv_path, header=None)  #header=None是去掉表头部分
        # 计算 length
        
        
        self.data_len = len(self.data_info.index) - 1
        self.train_len = int(self.data_len * (1 - valid_ratio))
        if mode == 'train':
            # 第一列包含图像文件的名称
            self.train_image = np.asarray(self.data_info.iloc[1:self.train_len, 1])  #self.data_info.iloc[1:,0]表示读取第一列，从第二行开始到train_len
            # 第二列是图像的 label
            self.train_label = np.asarray(self.data_info.iloc[1:self.train_len, 2])
            self.image_arr = self.train_image 
            self.label_arr = self.train_label
        elif mode == 'valid':
            self.valid_image = np.asarray(self.data_info.iloc[self.train_len:, 1])  
            self.valid_label = np.asarray(self.data_info.iloc[self.train_len:, 2])
            self.image_arr = self.valid_image
            self.label_arr = self.valid_label
        elif mode == 'test':
            self.test_image = np.asarray(self.data_info.iloc[1:, 0])
            self.image_arr = self.test_image
            
        self.real_len = len(self.image_arr)
        print('Finished reading the {} set of Leaves Dataset ({} samples found)'
              .format(mode, self.real_len))
    def __getitem__(self, index):
        # 从 image_arr中得到索引对应的文件名
        print(self.image_arr[index])
        
        # 读取图像文件
        img_as_img = Image.open(self.image_arr[index])

        #如果需要将RGB三通道的图片转换成灰度图片可参考下面两行
#         if img_as_img.mode != 'L':
#             img_as_img = img_as_img.convert('L')

        #设置好需要转换的变量，还可以包括一系列的nomarlize等等操作
        if self.mode == 'train':
            transform = transforms.Compose([
                transforms.Resize((224, 224)),
                transforms.RandomHorizontalFlip(p=0.5),   #随机水平翻转 选择一个概率
                transforms.ToTensor()
            ])
        else:
            # valid和test不做数据增强
            transform = transforms.Compose([
                transforms.Resize((224, 224)),
                transforms.ToTensor()
            ])
        
        img_as_img = transform(img_as_img)
        
        if self.mode == 'test':
            return img_as_img
        else:
            # 得到图像的 string label
            label = self.label_arr[index]
            # number label
            number_label = label
        

            return img_as_img, number_label  #返回每一个index对应的图片数据和对应的label

    def __len__(self):
        return self.real_len

# %%
path
# Out:
# '../garbage_classify_et/train_data/'

# %%
train_path = 'garbage_classify_et.csv'
img_path = path
train_dataset = GarbageData(train_path, img_path, mode='train')
val_dataset = GarbageData(train_path, img_path, mode='valid')
print(train_dataset)
print(val_dataset)
# Out:
# Finished reading the train set of Leaves Dataset (3331 samples found)
# Finished reading the valid set of Leaves Dataset (834 samples found)
# <__main__.GarbageData object at 0x000002BDD1FCF148>
# <__main__.GarbageData object at 0x000002BDD27F0E08>

# %%
train_loader = torch.utils.data.DataLoader(
        dataset=train_dataset,
        batch_size=8, 
        shuffle=True
        num_workers=0
    )

val_loader = torch.utils.data.DataLoader(
        dataset=val_dataset,
        batch_size=8, 
        shuffle=False,
        num_workers=0
    )

# %%
dataiter = iter(val_loader)

# %%
inputs, classes = dataiter.next()
# Out:
# ../garbage_classify_et/train_data/fimg_3353.jpg
# ../garbage_classify_et/train_data/fimg_3354.jpg
# ../garbage_classify_et/train_data/fimg_3355.jpg
# ../garbage_classify_et/train_data/fimg_3356.jpg
# ../garbage_classify_et/train_data/fimg_3357.jpg
# ../garbage_classify_et/train_data/fimg_3358.jpg
# ../garbage_classify_et/train_data/fimg_3359.jpg
# ../garbage_classify_et/train_data/fimg_3360.jpg

# %%
classes
# Out:
# ('28', '28', '28', '28', '28', '28', '28', '28')

# %%
# 给大家展示一下数据长啥样
def im_convert(tensor):
    """ 展示数据"""
    
    image = tensor.to("cpu").clone().detach()
    image = image.numpy().squeeze()
    image = image.transpose(1,2,0)
    image = image.clip(0, 1)

    return image

fig=plt.figure(figsize=(20, 12))
columns = 4
rows = 2

dataiter = iter(val_loader)
inputs, classes = dataiter.next()

for idx in range (columns*rows):
    ax = fig.add_subplot(rows, columns, idx+1, xticks=[], yticks=[])
    ax.set_title(json_data[str(int(classes[idx]))])
    plt.imshow(im_convert(inputs[idx]))
plt.show()
# Out:
# ../garbage_classify_et/train_data/fimg_3353.jpg
# ../garbage_classify_et/train_data/fimg_3354.jpg
# ../garbage_classify_et/train_data/fimg_3355.jpg
# ../garbage_classify_et/train_data/fimg_3356.jpg
# ../garbage_classify_et/train_data/fimg_3357.jpg
# ../garbage_classify_et/train_data/fimg_3358.jpg
# ../garbage_classify_et/train_data/fimg_3359.jpg
# ../garbage_classify_et/train_data/fimg_3360.jpg
